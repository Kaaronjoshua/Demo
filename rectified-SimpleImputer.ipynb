# %%
import pandas as pd
import numpy as np
df=pd.read_csv('car details v4.csv')
df.shape
# Out:
# (2059, 20)

# %%
df.shape
# Out:
# (2059, 20)

# %%
df.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
df=df.drop(['Make','Model','Location','Color','Engine','Max Power','Max Torque','Drivetrain'],axis=True)

# %%
df.rename(columns={'Seating Capacity':'Seating_Capacity'},inplace=True)

# %%
df.rename(columns={'Fuel Tank Capacity':'Fuel_Tank_Capacity'},inplace=True)

# %%
df
# Out:
#         Price  Year  Kilometer Fuel Type Transmission   Owner Seller Type  \
# 0      505000  2017      87150    Petrol       Manual   First   Corporate
# 1      450000  2014      75000    Diesel       Manual  Second  Individual
# 2      220000  2011      67000    Petrol       Manual   First  Individual
# 3      799000  2019      37500    Petrol       Manual   First  Individual
# 4     1950000  2018      69000    Diesel       Manual   First  Individual
# ...       ...   ...        ...       ...          ...     ...         ...
# 2054   850000  2016      90300    Diesel       Manual   First  Individual
# 2055   275000  2014      83000    Petrol       Manual  Second  Individual
# 2056   240000  2013      73000    Petrol       Manual   First  Individual
# 2057  4290000  2018      60474    Diesel    Automatic   First  Individual
# 2058   670000  2017      72000    Diesel       Manual   First  Individual
#
#       Length   Width  Height  Seating_Capacity  Fuel_Tank_Capacity
# ...

# %%
df.isnull().sum()
# Out:
# Price                   0
# Year                    0
# Kilometer               0
# Fuel Type               0
# Transmission            0
# Owner                   0
# Seller Type             0
# Length                 64
# Width                  64
# Height                 64
# Seating_Capacity       64
# Fuel_Tank_Capacity    113
# dtype: int64

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
columns_to_impute=['Length','Width','Height','Seating_Capacity','Fuel_Tank_Capacity']
df[columns_to_impute]=imputer.fit_transform(df[columns_to_impute])

# %%
df.isnull().sum()
# Out:
# Price                 0
# Year                  0
# Kilometer             0
# Fuel Type             0
# Transmission          0
# Owner                 0
# Seller Type           0
# Length                0
# Width                 0
# Height                0
# Seating_Capacity      0
# Fuel_Tank_Capacity    0
# dtype: int64

# %%
X=df.iloc
# Out:
#         Price  Year  Kilometer Fuel Type Transmission   Owner Seller Type  \
# 0      505000  2017      87150    Petrol       Manual   First   Corporate
# 1      450000  2014      75000    Diesel       Manual  Second  Individual
# 2      220000  2011      67000    Petrol       Manual   First  Individual
# 3      799000  2019      37500    Petrol       Manual   First  Individual
# 4     1950000  2018      69000    Diesel       Manual   First  Individual
# ...       ...   ...        ...       ...          ...     ...         ...
# 2054   850000  2016      90300    Diesel       Manual   First  Individual
# 2055   275000  2014      83000    Petrol       Manual  Second  Individual
# 2056   240000  2013      73000    Petrol       Manual   First  Individual
# 2057  4290000  2018      60474    Diesel    Automatic   First  Individual
# 2058   670000  2017      72000    Diesel       Manual   First  Individual
#
#       Length   Width  Height  Seating_Capacity  Fuel_Tank_Capacity
# ...
