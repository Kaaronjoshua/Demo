# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('titanic-test.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df=df.drop(['Cabin','Ticket','Name','PassengerId'],axis=True)

# %%
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 413       3    male   NaN      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male   NaN      0      0    8.0500        S
# 417       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
Y=df.iloc[:,5:6].values
Y
# Out:
# array([[  7.8292],
#        [  7.    ],
#        [  9.6875],
#        [  8.6625],
#        [ 12.2875],
#        [  9.225 ],
#        [  7.6292],
#        [ 29.    ],
#        [  7.2292],
#        [ 24.15  ],
#        [  7.8958],
#        [ 26.    ],
#        [ 82.2667],
#        [ 26.    ],
#        [ 61.175 ],
#        [ 27.7208],
#        [ 12.35  ],
#        [  7.225 ],
#        [  7.925 ],
#        [  7.225 ],
#        [ 59.4   ],
#        [  3.1708],
#        [ 31.6833],
#        [ 61.3792],
#        [262.375 ],
#        [ 14.5   ],
#        [ 61.9792],
#        [  7.225 ],
#        [ 30.5   ],
#        [ 21.6792],
#        [ 26.    ],
#        [ 31.5   ],
#        [ 20.575 ],
#        [ 23.45  ],
#        [ 57.75  ],
#        [  7.2292],
#        [  8.05  ],
#        [  8.6625],
#        [  9.5   ],
#        [ 56.4958],
#        [ 13.4167],
#        [ 26.55  ],
#        [  7.85  ],
#        [ 13.    ],
#        [ 52.5542],
#        [  7.925 ],
#        [ 29.7   ],
# ...

# %%
X=df.iloc[:,0:5].values
X
# Out:
# array([[3, 'male', 34.5, 0, 0],
#        [3, 'female', 47.0, 1, 0],
#        [2, 'male', 62.0, 0, 0],
#        ...,
#        [3, 'male', 38.5, 0, 0],
#        [3, 'male', nan, 0, 0],
#        [3, 'male', nan, 1, 1]], dtype=object)

# %%
impt=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
from sklearn.impute import SimpleImputer
impt_Y=SimpleImputer(missing_values=np.nan,strategy='mean')
X[:,2:3]=impt.fit_transform(X[:,2:3])
impt_Y=SimpleImputer(missing_values=np.nan,strategy='mean')
Y=impt.fit_transform(Y)

# %%
X
# Out:
# array([[3, 'male', 34.5, 0, 0],
#        [3, 'female', 47.0, 1, 0],
#        [2, 'male', 62.0, 0, 0],
#        ...,
#        [3, 'male', 38.5, 0, 0],
#        [3, 'male', 30.272590361445783, 0, 0],
#        [3, 'male', 30.272590361445783, 1, 1]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X[:,1]=le.fit_transform(X[:,1])
X
# Out:
# array([[3, 1, 34.5, 0, 0],
#        [3, 0, 47.0, 1, 0],
#        [2, 1, 62.0, 0, 0],
#        ...,
#        [3, 1, 38.5, 0, 0],
#        [3, 1, 30.272590361445783, 0, 0],
#        [3, 1, 30.272590361445783, 1, 1]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
# array([[3, 1, 39.0, 0, 2],
#        [1, 0, 53.0, 0, 0],
#        [3, 0, 22.0, 2, 0],
#        ...,
#        [3, 1, 24.0, 0, 0],
#        [3, 1, 20.0, 0, 0],
#        [3, 0, 21.0, 0, 0]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression

# %%
SLinear_reg=LinearRegression()
SLinear_reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
SLinear_reg.predict([[ 3, 1, 24.0, 0, 0]])
# Out:
# array([[-5.12927102]])

# %%
X1=df.iloc[:,0:1].values
X1
# Out:
# array([[3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [2],
#        [2],
#        [3],
#        [3],
#        [1],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [3],
#        [3],
#        [1],
#        [2],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
# ...

# %%
Y1=df.iloc[:,2:3].values
Y1
# Out:
# array([[34.5 ],
#        [47.  ],
#        [62.  ],
#        [27.  ],
#        [22.  ],
#        [14.  ],
#        [30.  ],
#        [26.  ],
#        [18.  ],
#        [21.  ],
#        [  nan],
#        [46.  ],
#        [23.  ],
#        [63.  ],
#        [47.  ],
#        [24.  ],
#        [35.  ],
#        [21.  ],
#        [27.  ],
#        [45.  ],
#        [55.  ],
#        [ 9.  ],
#        [  nan],
#        [21.  ],
#        [48.  ],
#        [50.  ],
#        [22.  ],
#        [22.5 ],
#        [41.  ],
#        [  nan],
#        [50.  ],
#        [24.  ],
#        [33.  ],
#        [  nan],
#        [30.  ],
#        [18.5 ],
#        [  nan],
#        [21.  ],
#        [25.  ],
#        [  nan],
#        [39.  ],
#        [  nan],
#        [41.  ],
#        [30.  ],
#        [45.  ],
#        [25.  ],
#        [45.  ],
#        [  nan],
#        [60.  ],
#        [36.  ],
#        [24.  ],
#        [27.  ],
#        [20.  ],
#        [28.  ],
#        [  nan],
# ...

# %%
impt_Y1=SimpleImputer(missing_values=np.nan,strategy='mean')
Y1=impt.fit_transform(Y1)

# %%
reg=LinearRegression()
reg.fit(X1,Y1)
# Out:
# LinearRegression()

# %%
plt.scatter(X1,Y1,color='red',marker='+')
plt.plot(X1,reg.predict(X1),color='blue')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=10)
X_poly=poly.fit_transform(X1)
reg_1=LinearRegression()
reg_1.fit(X_poly,Y1)
# Out:
# LinearRegression()

# %%
X_grid=np.arange(min(X1),max(X1),0.1)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X1,Y1,color='red',marker='+')
plt.plot(X_grid,reg_1.predict(poly.fit_transform(X_grid)))

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel='rbf')

# %%
sv.fit(X1,Y1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
X_grid=np.arange(min(X1),max(X1),0.1)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X1,Y1,color='red',marker='+')
plt.plot(X_grid,sv.predict(X_grid))

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(X1,Y1)
# Out:
# DecisionTreeRegressor()

# %%
X_grid=np.arange(min(X1),max(X1),0.1)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X1,Y1,color='red',marker='+')
plt.plot(X_grid,dtr.predict(X_grid))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rdr=RandomForestRegressor(n_estimators=100,random_state=0)

# %%
rdr.fit(X1,Y1)
# Out:
# C:\Users\General\AppData\Local\Temp\ipykernel_3064\2653732518.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rdr.fit(X1,Y1)
# RandomForestRegressor(random_state=0)

# %%
X_grid=np.arange(min(X1),max(X1),0.1)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X1,Y1,color='red',marker='+')
plt.plot(X_grid,rdr.predict(X_grid))
