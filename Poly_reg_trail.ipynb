# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('House_Train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df=df.drop(['Id','MSSubClass','MSZoning','LotFrontage','Street','Alley','LotShape','LandContour','Utilities'],axis=1)

# %%
df.head()
# Out:
#    LotArea LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0     8450    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1     9600       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    11250    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3     9550    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    14260       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  ...  PoolArea  PoolQC Fence  \
# 0     2Story            7            5  ...         0     NaN   NaN
# 1     1Story            6            8  ...         0     NaN   NaN
# 2     2Story            7            5  ...         0     NaN   NaN
# 3     2Story            7            5  ...         0     NaN   NaN
# 4     2Story            8            5  ...         0     NaN   NaN
#
#   MiscFeature MiscVal MoSold YrSold  SaleType SaleCondition SalePrice
# ...

# %%
df=df.drop(['LotConfig','LandSlope',	'Neighborhood',	'Condition1',	'Condition2',	'BldgType',	'HouseStyle',	'OverallQual',	'OverallCond'],axis=1)

# %%
df.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 0     8450       2003          2003     Gable  CompShg     VinylSd
# 1     9600       1976          1976     Gable  CompShg     MetalSd
# 2    11250       2001          2002     Gable  CompShg     VinylSd
# 3     9550       1915          1970     Gable  CompShg     Wd Sdng
# 4    14260       2000          2000     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual  ... PoolArea PoolQC Fence  \
# 0     VinylSd    BrkFace       196.0        Gd  ...        0    NaN   NaN
# 1     MetalSd       None         0.0        TA  ...        0    NaN   NaN
# 2     VinylSd    BrkFace       162.0        Gd  ...        0    NaN   NaN
# 3     Wd Shng       None         0.0        TA  ...        0    NaN   NaN
# 4     VinylSd    BrkFace       350.0        Gd  ...        0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold SaleType  SaleCondition  SalePrice
# ...

# %%
X=df.iloc[:,0:1].values
X
# Out:
# array([[ 8450],
#        [ 9600],
#        [11250],
#        ...,
#        [ 9042],
#        [ 9717],
#        [ 9937]], dtype=int64)

# %%
X.shape
# Out:
# (1460, 1)

# %%
Y.shape
# Out:
# (1460,)

# %%
Y=df.iloc[:,-1].values
Y
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500], dtype=int64)

# %%
plt.scatter(X,Y,color='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,reg.predict(X_train),color='blue')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polyf=PolynomialFeatures(degree=3)
X_poly=polyf.fit_transform(X_train)
reg1=LinearRegression()
reg1.fit(X_poly,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,reg1.predict(X_poly),color='blue')
plt.show()

# %%
X_grid=np.arange(min(X_train),max(X_train),0.1)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_grid,reg1.predict(polyf.fit_transform(X_grid)),color='blue')
plt.show()

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X=df.iloc[:,0:4]
X
# Out:
#         Id  MSSubClass MSZoning  LotFrontage
# 0        1          60       RL         65.0
# 1        2          20       RL         80.0
# 2        3          60       RL         68.0
# 3        4          70       RL         60.0
# 4        5          60       RL         84.0
# ...    ...         ...      ...          ...
# 1455  1456          60       RL         62.0
# 1456  1457          20       RL         85.0
# 1457  1458          70       RL         66.0
# 1458  1459          20       RL         68.0
# 1459  1460          20       RL         75.0
#
# [1460 rows x 4 columns]

# %%
X=X.drop(['MSZoning','Id'],axis=1)

# %%
Y=df.iloc[:,-1].values
Y
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500], dtype=int64)

# %%
X.isnull().sum()
# Out:
# MSSubClass       0
# LotFrontage    259
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
simp=SimpleImputer(missing_values=np.nan,strategy='mean')
X[:-1]=simp.fit_transform(X[:-1])

# %%
X.isnull().sum()
# Out:
# MSSubClass     0
# LotFrontage    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       MSSubClass  LotFrontage
# 921         90.0         67.0
# 520        190.0         60.0
# 401         20.0         65.0
# 280         60.0         82.0
# 1401        60.0         62.0
# ...          ...          ...
# 715         20.0         78.0
# 905         20.0         80.0
# 1096        70.0         60.0
# 235        160.0         21.0
# 1061        30.0        120.0
#
# [1168 rows x 2 columns]

# %%
X_test
# Out:
#       MSSubClass  LotFrontage
# 258         60.0    80.000000
# 267         75.0    60.000000
# 288         20.0    70.045833
# 649        180.0    21.000000
# 1233        20.0    70.045833
# ...          ...          ...
# 163         45.0    55.000000
# 47          20.0    84.000000
# 1432        30.0    60.000000
# 98          30.0    85.000000
# 409         60.0    85.000000
#
# [292 rows x 2 columns]

# %%
Lreg=LinearRegression()
Lreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=Lreg.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((Y_pred.reshape(len(Y_pred),1),Y_test.reshape(len(Y_test),1)),axis=1))
# Out:
# [[192651.43 231500.  ]
#  [171795.63 179500.  ]
#  [181360.05 122000.  ]
#  [132581.12  84500.  ]
#  [181360.05 142000.  ]
#  [198994.57 325624.  ]
#  [206394.89 285000.  ]
#  [141711.85 151000.  ]
#  [151421.06 195000.  ]
#  [182511.97 275000.  ]
#  [181311.6  175000.  ]
#  [181552.04  61000.  ]
#  [165259.25 174000.  ]
#  [179197.22 385000.  ]
#  [181360.05 230000.  ]
#  [162858.16  87000.  ]
#  [211970.08 125000.  ]
#  [197169.43  98600.  ]
#  [181744.03 260000.  ]
#  [162087.68 143000.  ]
#  [170739.71 124000.  ]
#  [174003.48 122500.  ]
#  [150458.6  236500.  ]
#  [208798.51 337500.  ]
#  [171219.67  76000.  ]
#  [192651.43 187000.  ]
#  [171699.64 128000.  ]
#  [176025.65 179000.  ]
#  [218023.97 485000.  ]
#  [135368.71 122500.  ]
#  [203511.3  106000.  ]
#  [132197.15 118000.  ]
#  [170739.71 127000.  ]
#  [174003.48  80000.  ]
#  [185540.35 153000.  ]
#  [202455.38 360000.  ]
#  [160167.82 132000.  ]
#  [161416.99  85500.  ]
#  [198994.57 262280.  ]
#  [181887.56 112000.  ]
# ...
