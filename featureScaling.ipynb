# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("heart(1).csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
col_to_scale=['Cholesterol','Oldpeak']

# %%
scaler= StandardScaler()

# %%
df[col_to_scale]=scaler.fit_transform(df[col_to_scale])

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140     0.825070          0     Normal
# 1     49   F           NAP        160    -0.171961          0     Normal
# 2     37   M           ATA        130     0.770188          0         ST
# 3     48   F           ASY        138     0.139040          0     Normal
# 4     54   M           NAP        150    -0.034755          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110     0.596393          0     Normal
# 914   68   M           ASY        144    -0.053049          1     Normal
# 915   57   M           ASY        130    -0.620168          0     Normal
# 916   57   F           ATA        130     0.340275          0        LVH
# 917   38   M           NAP        138    -0.217696          0     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# ...

# %%
mscaler=MinMaxScaler()
df[col_to_scale]=mscaler.fit_transform(df[col_to_scale])

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140     0.479270          0     Normal
# 1     49   F           NAP        160     0.298507          0     Normal
# 2     37   M           ATA        130     0.469320          0         ST
# 3     48   F           ASY        138     0.354892          0     Normal
# 4     54   M           NAP        150     0.323383          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110     0.437811          0     Normal
# 914   68   M           ASY        144     0.320066          1     Normal
# 915   57   M           ASY        130     0.217247          0     Normal
# 916   57   F           ATA        130     0.391376          0        LVH
# 917   38   M           NAP        138     0.290216          0     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# ...

# %%
#for l1 and l2 we get ----> Norscaler=Normailzer(norm='l1' or 'l2')
Norscaler=Normalizer()
df[col_to_scale]=Norscaler.fit_transform(df[col_to_scale])

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140     0.851247          0     Normal
# 1     49   F           NAP        160     0.589445          0     Normal
# 2     37   M           ATA        130     0.846268          0         ST
# 3     48   F           ASY        138     0.605950          0     Normal
# 4     54   M           NAP        150     0.738268          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110     0.711963          0     Normal
# 914   68   M           ASY        144     0.424939          1     Normal
# 915   57   M           ASY        130     0.449427          0     Normal
# 916   57   F           ATA        130     0.798115          0        LVH
# 917   38   M           NAP        138     0.700754          0     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# ...
